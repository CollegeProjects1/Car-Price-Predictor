# %%
import pandas as pd
dataset1=pd.read_csv("Cardekho_Extract.csv")
dataset1
# Out:
#                             Source.Name web-scraper-order  \
# 0          cardekho_extract(0-2000).csv   1611917819-1662
# 1          cardekho_extract(0-2000).csv   1611918361-1902
# 2          cardekho_extract(0-2000).csv   1611917012-1306
# 3          cardekho_extract(0-2000).csv   1611917695-1607
# 4          cardekho_extract(0-2000).csv    1611914861-367
# ...                                 ...               ...
# 20021  cardekho_extract(5001-10000).csv   1612103494-3517
# 20022  cardekho_extract(5001-10000).csv    1612096792-548
# 20023  cardekho_extract(5001-10000).csv   1612105576-4445
# 20024  cardekho_extract(5001-10000).csv   1612100458-2178
# 20025  cardekho_extract(5001-10000).csv   1612098778-1432
#
#                                    web-scraper-start-url  \
# 0      https://www.cardekho.com/used-car-details/used...
# 1      https://www.cardekho.com/used-car-details/used...
# 2      https://www.cardekho.com/used-car-details/used...
# ...

# %%
dataset1.columns
# Out:
# Index(['Source.Name', 'web-scraper-order', 'web-scraper-start-url',
#        'full_name', 'selling_price', 'new-price', 'year', 'seller_type',
#        'km_driven', 'owner_type', 'fuel_type', 'transmission_type', 'mileage',
#        'engine', 'max_power', 'seats'],
#       dtype='object')

# %%
dataset1.isna().sum()
# Out:
# Source.Name                  0
# web-scraper-order            0
# web-scraper-start-url        0
# full_name                   46
# selling_price               46
# new-price                10460
# year                        46
# seller_type                 46
# km_driven                   46
# owner_type                  46
# fuel_type                   46
# transmission_type           46
# mileage                     46
# engine                     105
# max_power                  105
# seats                      173
# dtype: int64

# %%
(20026-10456)
# Out:
# 9570

# %%
dataset1.info()
backup=dataset1.copy()
data=pd.DataFrame(dataset1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20026 entries, 0 to 20025
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Source.Name            20026 non-null  object
#  1   web-scraper-order      20026 non-null  object
#  2   web-scraper-start-url  20026 non-null  object
#  3   full_name              19980 non-null  object
#  4   selling_price          19980 non-null  object
#  5   new-price              9566 non-null   object
#  6   year                   19980 non-null  float64
#  7   seller_type            19980 non-null  object
#  8   km_driven              19980 non-null  object
#  9   owner_type             19980 non-null  object
#  10  fuel_type              19980 non-null  object
#  11  transmission_type      19980 non-null  object
#  12  mileage                19980 non-null  object
#  13  engine                 19921 non-null  object
# ...

# %%
data=data.drop(['Source.Name','web-scraper-order','web-scraper-start-url'],axis=1)
data.head()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20026 entries, 0 to 20025
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   full_name          19980 non-null  object
#  1   selling_price      19980 non-null  object
#  2   new-price          9566 non-null   object
#  3   year               19980 non-null  float64
#  4   seller_type        19980 non-null  object
#  5   km_driven          19980 non-null  object
#  6   owner_type         19980 non-null  object
#  7   fuel_type          19980 non-null  object
#  8   transmission_type  19980 non-null  object
#  9   mileage            19980 non-null  object
#  10  engine             19921 non-null  object
#  11  max_power          19921 non-null  object
#  12  seats              19853 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 2.0+ MB

# %%
from numpy import NaN
data.dropna(inplace=True)
data.info()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9492 entries, 1 to 20024
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   full_name          9492 non-null   object
#  1   selling_price      9492 non-null   object
#  2   new-price          9492 non-null   object
#  3   year               9492 non-null   float64
#  4   seller_type        9492 non-null   object
#  5   km_driven          9492 non-null   object
#  6   owner_type         9492 non-null   object
#  7   fuel_type          9492 non-null   object
#  8   transmission_type  9492 non-null   object
#  9   mileage            9492 non-null   object
#  10  engine             9492 non-null   object
#  11  max_power          9492 non-null   object
#  12  seats              9492 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 1.0+ MB
#                                         full_name selling_price  \
# ...

# %%
data['selling_price']=data['selling_price'].str.split(' ').str.get(0)

# %%
data.head()
# Out:
#                                         full_name selling_price  \
# 1                          Hyundai Grand i10 Asta           5.5
# 4  Ford Ecosport 2015-2021 1.5 TDCi Titanium BSIV           5.7
# 5                        Maruti Wagon R VXI BS IV           3.5
# 6                          Hyundai i10 Sportz 1.2          3.15
# 7                              Maruti Wagon R VXI           4.1
#
#                                         new-price    year seller_type  \
# 1    New Car (On-Road Price) : Rs.7.11-7.48 Lakh*  2016.0  Individual
# 4  New Car (On-Road Price) : Rs.10.14-13.79 Lakh*  2015.0      Dealer
# 5    New Car (On-Road Price) : Rs.5.16-6.94 Lakh*  2013.0  Individual
# 6    New Car (On-Road Price) : Rs.6.54-6.63 Lakh*  2013.0      Dealer
# 7    New Car (On-Road Price) : Rs.5.26-7.01 Lakh*  2018.0      Dealer
#
#     km_driven   owner_type fuel_type transmission_type            mileage  \
# 1  20,000 kms  First Owner    Petrol            Manual   Mileage18.9 kmpl
# ...

# %%
data['km_driven']=data['km_driven'].str.split(' ').str.get(0)
data['km_driven']=data['km_driven'].str.replace(',','')
data.head()
# Out:
#                                         full_name selling_price  \
# 1                          Hyundai Grand i10 Asta           5.5
# 4  Ford Ecosport 2015-2021 1.5 TDCi Titanium BSIV           5.7
# 5                        Maruti Wagon R VXI BS IV           3.5
# 6                          Hyundai i10 Sportz 1.2          3.15
# 7                              Maruti Wagon R VXI           4.1
#
#                                         new-price    year seller_type  \
# 1    New Car (On-Road Price) : Rs.7.11-7.48 Lakh*  2016.0  Individual
# 4  New Car (On-Road Price) : Rs.10.14-13.79 Lakh*  2015.0      Dealer
# 5    New Car (On-Road Price) : Rs.5.16-6.94 Lakh*  2013.0  Individual
# 6    New Car (On-Road Price) : Rs.6.54-6.63 Lakh*  2013.0      Dealer
# 7    New Car (On-Road Price) : Rs.5.26-7.01 Lakh*  2018.0      Dealer
#
#   km_driven   owner_type fuel_type transmission_type            mileage  \
# 1     20000  First Owner    Petrol            Manual   Mileage18.9 kmpl
# ...

# %%
mileage=data['mileage'].str.split(' ').str.get(0)
data['mileage']=mileage.str.slice(7,)
data.head()
# Out:
#                                         full_name selling_price  \
# 1                          Hyundai Grand i10 Asta           5.5
# 4  Ford Ecosport 2015-2021 1.5 TDCi Titanium BSIV           5.7
# 5                        Maruti Wagon R VXI BS IV           3.5
# 6                          Hyundai i10 Sportz 1.2          3.15
# 7                              Maruti Wagon R VXI           4.1
#
#                                         new-price    year seller_type  \
# 1    New Car (On-Road Price) : Rs.7.11-7.48 Lakh*  2016.0  Individual
# 4  New Car (On-Road Price) : Rs.10.14-13.79 Lakh*  2015.0      Dealer
# 5    New Car (On-Road Price) : Rs.5.16-6.94 Lakh*  2013.0  Individual
# 6    New Car (On-Road Price) : Rs.6.54-6.63 Lakh*  2013.0      Dealer
# 7    New Car (On-Road Price) : Rs.5.26-7.01 Lakh*  2018.0      Dealer
#
#   km_driven   owner_type fuel_type transmission_type mileage         engine  \
# 1     20000  First Owner    Petrol            Manual    18.9  Engine1197 CC
# ...

# %%
max_power=data['max_power'].str.split(' ').str.get(1)
data['max_power']=max_power.str.slice(5,)
data.head()
# Out:
#                                         full_name selling_price  \
# 1                          Hyundai Grand i10 Asta           5.5
# 4  Ford Ecosport 2015-2021 1.5 TDCi Titanium BSIV           5.7
# 5                        Maruti Wagon R VXI BS IV           3.5
# 6                          Hyundai i10 Sportz 1.2          3.15
# 7                              Maruti Wagon R VXI           4.1
#
#                                         new-price    year seller_type  \
# 1    New Car (On-Road Price) : Rs.7.11-7.48 Lakh*  2016.0  Individual
# 4  New Car (On-Road Price) : Rs.10.14-13.79 Lakh*  2015.0      Dealer
# 5    New Car (On-Road Price) : Rs.5.16-6.94 Lakh*  2013.0  Individual
# 6    New Car (On-Road Price) : Rs.6.54-6.63 Lakh*  2013.0      Dealer
# 7    New Car (On-Road Price) : Rs.5.26-7.01 Lakh*  2018.0      Dealer
#
#   km_driven   owner_type fuel_type transmission_type mileage         engine  \
# 1     20000  First Owner    Petrol            Manual    18.9  Engine1197 CC
# ...

# %%
engine=data['engine'].str.split(' ').str.get(0)
data['engine']=engine.str.slice(6,)
data.head()
# Out:
#                                         full_name selling_price  \
# 1                          Hyundai Grand i10 Asta           5.5
# 4  Ford Ecosport 2015-2021 1.5 TDCi Titanium BSIV           5.7
# 5                        Maruti Wagon R VXI BS IV           3.5
# 6                          Hyundai i10 Sportz 1.2          3.15
# 7                              Maruti Wagon R VXI           4.1
#
#                                         new-price    year seller_type  \
# 1    New Car (On-Road Price) : Rs.7.11-7.48 Lakh*  2016.0  Individual
# 4  New Car (On-Road Price) : Rs.10.14-13.79 Lakh*  2015.0      Dealer
# 5    New Car (On-Road Price) : Rs.5.16-6.94 Lakh*  2013.0  Individual
# 6    New Car (On-Road Price) : Rs.6.54-6.63 Lakh*  2013.0      Dealer
# 7    New Car (On-Road Price) : Rs.5.26-7.01 Lakh*  2018.0      Dealer
#
#   km_driven   owner_type fuel_type transmission_type mileage engine max_power  \
# ...

# %%
newprice=data['new-price'].str.split('-').str.get(2)
newprice=newprice.str.split(' ').str.get(0)
data['new-price']=newprice
data.head()
# Out:
#                                         full_name selling_price new-price  \
# 1                          Hyundai Grand i10 Asta           5.5      7.48
# 4  Ford Ecosport 2015-2021 1.5 TDCi Titanium BSIV           5.7     13.79
# 5                        Maruti Wagon R VXI BS IV           3.5      6.94
# 6                          Hyundai i10 Sportz 1.2          3.15      6.63
# 7                              Maruti Wagon R VXI           4.1      7.01
#
#      year seller_type km_driven   owner_type fuel_type transmission_type  \
# 1  2016.0  Individual     20000  First Owner    Petrol            Manual
# 4  2015.0      Dealer     30000  First Owner    Diesel            Manual
# 5  2013.0  Individual     35000  First Owner    Petrol            Manual
# 6  2013.0      Dealer     40000  First Owner    Petrol            Manual
# 7  2018.0      Dealer     17512  First Owner    Petrol            Manual
#
#   mileage engine max_power   seats
# 1    18.9   1197        82  Seats5
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9492 entries, 1 to 20024
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   full_name          9492 non-null   object
#  1   selling_price      9492 non-null   object
#  2   new-price          9208 non-null   object
#  3   year               9492 non-null   float64
#  4   seller_type        9492 non-null   object
#  5   km_driven          9492 non-null   object
#  6   owner_type         9492 non-null   object
#  7   fuel_type          9492 non-null   object
#  8   transmission_type  9492 non-null   object
#  9   mileage            9492 non-null   object
#  10  engine             9492 non-null   object
#  11  max_power          9492 non-null   object
#  12  seats              9492 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 1.0+ MB

# %%
data=data.drop(['seats'],axis=1)
data=data.drop(['engine','max_power'],axis=1)

# %%
data.head()
# Out:
#                                         full_name selling_price new-price  \
# 1                          Hyundai Grand i10 Asta           5.5      7.48
# 4  Ford Ecosport 2015-2021 1.5 TDCi Titanium BSIV           5.7     13.79
# 5                        Maruti Wagon R VXI BS IV           3.5      6.94
# 6                          Hyundai i10 Sportz 1.2          3.15      6.63
# 7                              Maruti Wagon R VXI           4.1      7.01
#
#      year seller_type km_driven   owner_type fuel_type transmission_type  \
# 1  2016.0  Individual     20000  First Owner    Petrol            Manual
# 4  2015.0      Dealer     30000  First Owner    Diesel            Manual
# 5  2013.0  Individual     35000  First Owner    Petrol            Manual
# 6  2013.0      Dealer     40000  First Owner    Petrol            Manual
# 7  2018.0      Dealer     17512  First Owner    Petrol            Manual
#
#   mileage
# 1    18.9
# 4   22.77
# 5    18.9
# 6   20.36
# 7   20.51

# %%
data['selling_price']=data['selling_price'].str.replace('*','')
data['selling_price']=data['selling_price'].str.replace(',','.')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9492 entries, 1 to 20024
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   full_name          9492 non-null   object
#  1   selling_price      9492 non-null   object
#  2   new-price          9208 non-null   object
#  3   year               9492 non-null   float64
#  4   seller_type        9492 non-null   object
#  5   km_driven          9492 non-null   object
#  6   owner_type         9492 non-null   object
#  7   fuel_type          9492 non-null   object
#  8   transmission_type  9492 non-null   object
#  9   mileage            9492 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 815.7+ KB
# ...

# %%
data['selling_price']=data['selling_price'].astype(float)
data['new-price']=data['new-price'].astype(float)
data['km_driven']=data['km_driven'].astype(float)
data['mileage']=data['mileage'].astype(float)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9492 entries, 1 to 20024
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   full_name          9492 non-null   object
#  1   selling_price      9492 non-null   float64
#  2   new-price          9208 non-null   float64
#  3   year               9492 non-null   float64
#  4   seller_type        9492 non-null   object
#  5   km_driven          9492 non-null   float64
#  6   owner_type         9492 non-null   object
#  7   fuel_type          9492 non-null   object
#  8   transmission_type  9492 non-null   object
#  9   mileage            9492 non-null   float64
# dtypes: float64(5), object(5)
# memory usage: 815.7+ KB

# %%
data['full_name']=data['full_name'].str.split(' ').str.slice(0,3).str.join(' ')
data['Brand']=data['full_name'].str.split(' ').str.get(0)
print()
data.info()
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9492 entries, 1 to 20024
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   full_name          9492 non-null   object
#  1   selling_price      9492 non-null   float64
#  2   new-price          9208 non-null   float64
#  3   year               9492 non-null   float64
#  4   seller_type        9492 non-null   object
#  5   km_driven          9492 non-null   float64
#  6   owner_type         9492 non-null   object
#  7   fuel_type          9492 non-null   object
#  8   transmission_type  9492 non-null   object
#  9   mileage            9492 non-null   float64
#  10  Brand              9492 non-null   object
# dtypes: float64(5), object(6)
# memory usage: 889.9+ KB
#                  full_name  selling_price  new-price    year seller_type  \
# 1        Hyundai Grand i10           5.50       7.48  2016.0  Individual
# ...

# %%
data.describe()
# Out:
#        selling_price    new-price         year     km_driven      mileage
# count    9492.000000  9208.000000  9492.000000  9.492000e+03  9492.000000
# mean        8.419127    16.926972  2015.274336  5.124817e+04    18.888194
# std         9.432015    15.994717     3.006256  5.558671e+04     4.052429
# min         1.000000     1.000000  1992.000000  1.000000e+02     0.000000
# 25%         4.000000     8.310000  2014.000000  2.500000e+04    16.200000
# 50%         5.750000    12.620000  2016.000000  4.600000e+04    18.900000
# 75%         8.750000    17.790000  2018.000000  6.700000e+04    21.790000
# max        95.000000    99.580000  2021.000000  3.800000e+06    33.540000

# %%
data['selling_price'].isna().sum()
# Out:
# 0

# %%
from numpy import nan

data['selling_price'].replace('',nan)
# Out:
# 1         5.50
# 4         5.70
# 5         3.50
# 6         3.15
# 7         4.10
#          ...
# 20008     2.75
# 20009     4.85
# 20011     5.90
# 20013     5.25
# 20024    12.25
# Name: selling_price, Length: 9492, dtype: float64

# %%
data['selling_price'].isna().sum()
# Out:
# 0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9492 entries, 1 to 20024
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   full_name          9492 non-null   object
#  1   selling_price      9492 non-null   float64
#  2   new-price          9208 non-null   float64
#  3   year               9492 non-null   float64
#  4   seller_type        9492 non-null   object
#  5   km_driven          9492 non-null   float64
#  6   owner_type         9492 non-null   object
#  7   fuel_type          9492 non-null   object
#  8   transmission_type  9492 non-null   object
#  9   mileage            9492 non-null   float64
#  10  Brand              9492 non-null   object
# dtypes: float64(5), object(6)
# memory usage: 889.9+ KB

# %%
data=data[data['new-price']>0.0]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9208 entries, 1 to 20024
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   full_name          9208 non-null   object
#  1   selling_price      9208 non-null   float64
#  2   new-price          9208 non-null   float64
#  3   year               9208 non-null   float64
#  4   seller_type        9208 non-null   object
#  5   km_driven          9208 non-null   float64
#  6   owner_type         9208 non-null   object
#  7   fuel_type          9208 non-null   object
#  8   transmission_type  9208 non-null   object
#  9   mileage            9208 non-null   float64
#  10  Brand              9208 non-null   object
# dtypes: float64(5), object(6)
# memory usage: 863.2+ KB

# %%
data.describe()
# Out:
#        selling_price    new-price         year     km_driven      mileage
# count    9208.000000  9208.000000  9208.000000  9.208000e+03  9208.000000
# mean        8.001657    16.926972  2015.262815  5.123596e+04    18.947037
# std         8.580270    15.994717     3.020476  5.617933e+04     4.043357
# min         1.000000     1.000000  1992.000000  1.000000e+02     0.000000
# 25%         4.000000     8.310000  2014.000000  2.500000e+04    16.380000
# 50%         5.650000    12.620000  2016.000000  4.590800e+04    18.900000
# 75%         8.500000    17.790000  2018.000000  6.700000e+04    21.790000
# max        95.000000    99.580000  2021.000000  3.800000e+06    33.540000

# %%
data=data[data['new-price']<30.0]

# %%
data.describe()
# Out:
#        selling_price    new-price         year     km_driven      mileage
# count    8308.000000  8308.000000  8308.000000  8.308000e+03  8308.000000
# mean        6.613184    12.436271  2015.351228  5.001244e+04    19.393128
# std         6.743060     5.620772     2.992932  5.571859e+04     3.840375
# min         1.000000     1.000000  1992.000000  1.000000e+02     0.000000
# 25%         3.800000     7.700000  2014.000000  2.500000e+04    17.000000
# 50%         5.350000    11.420000  2016.000000  4.500000e+04    18.900000
# 75%         7.500000    16.520000  2018.000000  6.569700e+04    22.000000
# max        95.000000    29.900000  2021.000000  3.800000e+06    33.540000

# %%
data=data[data['selling_price']<20.0]

# %%
data.describe()
# Out:
#        selling_price    new-price         year     km_driven      mileage
# count    8179.000000  8179.000000  8179.000000  8.179000e+03  8179.000000
# mean        5.953564    12.503818  2015.388801  5.004540e+04    19.486382
# std         3.115562     5.502518     2.909065  5.599593e+04     3.750110
# min         1.000000     1.020000  2003.000000  1.000000e+02     0.000000
# 25%         3.750000     7.750000  2014.000000  2.500000e+04    17.000000
# 50%         5.300000    11.450000  2016.000000  4.500000e+04    18.900000
# 75%         7.350000    16.520000  2018.000000  6.544050e+04    22.000000
# max        19.950000    29.900000  2021.000000  3.800000e+06    33.540000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8179 entries, 1 to 20024
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   full_name          8179 non-null   object
#  1   selling_price      8179 non-null   float64
#  2   new-price          8179 non-null   float64
#  3   year               8179 non-null   float64
#  4   seller_type        8179 non-null   object
#  5   km_driven          8179 non-null   float64
#  6   owner_type         8179 non-null   object
#  7   fuel_type          8179 non-null   object
#  8   transmission_type  8179 non-null   object
#  9   mileage            8179 non-null   float64
#  10  Brand              8179 non-null   object
# dtypes: float64(5), object(6)
# memory usage: 766.8+ KB

# %%
data.selling_price = data.selling_price.multiply(100000)
data.head()
# Out:
#                  full_name  selling_price  new-price    year seller_type  \
# 1        Hyundai Grand i10       550000.0       7.48  2016.0  Individual
# 4  Ford Ecosport 2015-2021       570000.0      13.79  2015.0      Dealer
# 5           Maruti Wagon R       350000.0       6.94  2013.0  Individual
# 6       Hyundai i10 Sportz       315000.0       6.63  2013.0      Dealer
# 7           Maruti Wagon R       410000.0       7.01  2018.0      Dealer
#
#    km_driven   owner_type fuel_type transmission_type  mileage    Brand
# 1    20000.0  First Owner    Petrol            Manual    18.90  Hyundai
# 4    30000.0  First Owner    Diesel            Manual    22.77     Ford
# 5    35000.0  First Owner    Petrol            Manual    18.90   Maruti
# 6    40000.0  First Owner    Petrol            Manual    20.36  Hyundai
# 7    17512.0  First Owner    Petrol            Manual    20.51   Maruti

# %%
data['new-price'] = data['new-price'].multiply(100000)
data.head()
# Out:
#                  full_name  selling_price  new-price    year seller_type  \
# 1        Hyundai Grand i10       550000.0   748000.0  2016.0  Individual
# 4  Ford Ecosport 2015-2021       570000.0  1379000.0  2015.0      Dealer
# 5           Maruti Wagon R       350000.0   694000.0  2013.0  Individual
# 6       Hyundai i10 Sportz       315000.0   663000.0  2013.0      Dealer
# 7           Maruti Wagon R       410000.0   701000.0  2018.0      Dealer
#
#    km_driven   owner_type fuel_type transmission_type  mileage    Brand
# 1    20000.0  First Owner    Petrol            Manual    18.90  Hyundai
# 4    30000.0  First Owner    Diesel            Manual    22.77     Ford
# 5    35000.0  First Owner    Petrol            Manual    18.90   Maruti
# 6    40000.0  First Owner    Petrol            Manual    20.36  Hyundai
# 7    17512.0  First Owner    Petrol            Manual    20.51   Maruti

# %%
data.describe()
# Out:
#        selling_price     new-price         year     km_driven      mileage
# count   8.179000e+03  8.179000e+03  8179.000000  8.179000e+03  8179.000000
# mean    5.953564e+05  1.250382e+06  2015.388801  5.004540e+04    19.486382
# std     3.115562e+05  5.502518e+05     2.909065  5.599593e+04     3.750110
# min     1.000000e+05  1.020000e+05  2003.000000  1.000000e+02     0.000000
# 25%     3.750000e+05  7.750000e+05  2014.000000  2.500000e+04    17.000000
# 50%     5.300000e+05  1.145000e+06  2016.000000  4.500000e+04    18.900000
# 75%     7.350000e+05  1.652000e+06  2018.000000  6.544050e+04    22.000000
# max     1.995000e+06  2.990000e+06  2021.000000  3.800000e+06    33.540000

# %%
data.reset_index(drop=True)
# Out:
#                     full_name  selling_price  new-price    year seller_type  \
# 0           Hyundai Grand i10       550000.0   748000.0  2016.0  Individual
# 1     Ford Ecosport 2015-2021       570000.0  1379000.0  2015.0      Dealer
# 2              Maruti Wagon R       350000.0   694000.0  2013.0  Individual
# 3          Hyundai i10 Sportz       315000.0   663000.0  2013.0      Dealer
# 4              Maruti Wagon R       410000.0   701000.0  2018.0      Dealer
# ...                       ...            ...        ...     ...         ...
# 8174          Maruti Alto 800       275000.0   502000.0  2014.0      Dealer
# 8175     Renault KWID Climber       485000.0   685000.0  2017.0      Dealer
# 8176         Maruti Swift AMT       590000.0   914000.0  2018.0  Individual
# 8177            Honda Amaze E       525000.0  1176000.0  2015.0      Dealer
# 8178       Mahindra XUV500 W6      1225000.0  2491000.0  2016.0      Dealer
#
# ...

# %%
data.describe()
# Out:
#        selling_price     new-price         year     km_driven      mileage
# count   8.179000e+03  8.179000e+03  8179.000000  8.179000e+03  8179.000000
# mean    5.953564e+05  1.250382e+06  2015.388801  5.004540e+04    19.486382
# std     3.115562e+05  5.502518e+05     2.909065  5.599593e+04     3.750110
# min     1.000000e+05  1.020000e+05  2003.000000  1.000000e+02     0.000000
# 25%     3.750000e+05  7.750000e+05  2014.000000  2.500000e+04    17.000000
# 50%     5.300000e+05  1.145000e+06  2016.000000  4.500000e+04    18.900000
# 75%     7.350000e+05  1.652000e+06  2018.000000  6.544050e+04    22.000000
# max     1.995000e+06  2.990000e+06  2021.000000  3.800000e+06    33.540000

# %%
data
# Out:
#                      full_name  selling_price  new-price    year seller_type  \
# 1            Hyundai Grand i10       550000.0   748000.0  2016.0  Individual
# 4      Ford Ecosport 2015-2021       570000.0  1379000.0  2015.0      Dealer
# 5               Maruti Wagon R       350000.0   694000.0  2013.0  Individual
# 6           Hyundai i10 Sportz       315000.0   663000.0  2013.0      Dealer
# 7               Maruti Wagon R       410000.0   701000.0  2018.0      Dealer
# ...                        ...            ...        ...     ...         ...
# 20008          Maruti Alto 800       275000.0   502000.0  2014.0      Dealer
# 20009     Renault KWID Climber       485000.0   685000.0  2017.0      Dealer
# 20011         Maruti Swift AMT       590000.0   914000.0  2018.0  Individual
# 20013            Honda Amaze E       525000.0  1176000.0  2015.0      Dealer
# 20024       Mahindra XUV500 W6      1225000.0  2491000.0  2016.0      Dealer
#
# ...

# %%
data=data.reset_index(drop=True)

# %%
data
# Out:
#                     full_name  selling_price  new-price    year seller_type  \
# 0           Hyundai Grand i10       550000.0   748000.0  2016.0  Individual
# 1     Ford Ecosport 2015-2021       570000.0  1379000.0  2015.0      Dealer
# 2              Maruti Wagon R       350000.0   694000.0  2013.0  Individual
# 3          Hyundai i10 Sportz       315000.0   663000.0  2013.0      Dealer
# 4              Maruti Wagon R       410000.0   701000.0  2018.0      Dealer
# ...                       ...            ...        ...     ...         ...
# 8174          Maruti Alto 800       275000.0   502000.0  2014.0      Dealer
# 8175     Renault KWID Climber       485000.0   685000.0  2017.0      Dealer
# 8176         Maruti Swift AMT       590000.0   914000.0  2018.0  Individual
# 8177            Honda Amaze E       525000.0  1176000.0  2015.0      Dealer
# 8178       Mahindra XUV500 W6      1225000.0  2491000.0  2016.0      Dealer
#
# ...

# %%
data['selling_price']=data['selling_price'].astype(int)
data['new-price']=data['new-price'].astype(int)
data['km_driven']=data['km_driven'].astype(int)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8179 entries, 0 to 8178
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   full_name          8179 non-null   object
#  1   selling_price      8179 non-null   int32
#  2   new-price          8179 non-null   int32
#  3   year               8179 non-null   float64
#  4   seller_type        8179 non-null   object
#  5   km_driven          8179 non-null   int32
#  6   owner_type         8179 non-null   object
#  7   fuel_type          8179 non-null   object
#  8   transmission_type  8179 non-null   object
#  9   mileage            8179 non-null   float64
#  10  Brand              8179 non-null   object
# dtypes: float64(2), int32(3), object(6)
# memory usage: 607.2+ KB

# %%
data['year']=data['year'].astype(int)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8179 entries, 0 to 8178
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   full_name          8179 non-null   object
#  1   selling_price      8179 non-null   int32
#  2   new-price          8179 non-null   int32
#  3   year               8179 non-null   int32
#  4   seller_type        8179 non-null   object
#  5   km_driven          8179 non-null   int32
#  6   owner_type         8179 non-null   object
#  7   fuel_type          8179 non-null   object
#  8   transmission_type  8179 non-null   object
#  9   mileage            8179 non-null   float64
#  10  Brand              8179 non-null   object
# dtypes: float64(1), int32(4), object(6)
# memory usage: 575.2+ KB

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline
mpl.style.use('ggplot')
import seaborn as sns

# %%
plt.subplots(figsize=(15,7))
ax=sns.boxplot(x='Brand',y='selling_price',data=data)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()

# %%
plt.subplots(figsize=(15,7))
ax=sns.swarmplot(x='year',y='selling_price',data=data)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:3544: UserWarning: 13.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:3544: UserWarning: 17.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\DELL\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\seaborn\categorical.py:3544: UserWarning: 31.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
sns.relplot(x='km_driven',y='selling_price',data=data,height=7,aspect=1.5)

# %%
plt.subplots(figsize=(14,7))
sns.boxplot(x='fuel_type',y='selling_price',data=data)
# Out:
# <AxesSubplot: xlabel='fuel_type', ylabel='selling_price'>

# %%
ax=sns.relplot(x='Brand',y='selling_price',data=data,hue='fuel_type',size='year',height=7,aspect=2)
ax.set_xticklabels(rotation=40,ha='right')

# %%
data.to_csv('PreProcessedData.csv')
